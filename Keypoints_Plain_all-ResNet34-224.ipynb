# %%
# import os
# !pip install torch torchvision feather-format kornia pyarrow Pillow wandb --upgrade 
# !pip install git+https://github.com/fastai/fastai_dev
# os._exit(00)

# %%
from fastai2.basics import *
from fastai2.vision.all import *
from fastai2.callback.all import *

# %%
# !gdown "https://drive.google.com/uc?id=1ffJr3NrYPqzutcXsYIVNLXzzUaC9RqYM"

# %%
# import zipfile
# with zipfile.ZipFile('cat-dataset.zip', 'r') as zip_ref:
#   zip_ref.extractall()

# %%
path = Path('data/cat/all');path.ls()
# Out:
# (#19987) [data/cat/all/00001474_006.jpg.cat,data/cat/all/00000343_015.jpg,data/cat/all/00000178_014.jpg.cat,data/cat/all/00000019_024.jpg.cat,data/cat/all/00001387_016.jpg,data/cat/all/00000564_019.jpg.cat,data/cat/all/00000573_028.jpg.cat,data/cat/all/00001085_005.jpg.cat,data/cat/all/00000938_011.jpg,data/cat/all/00001215_023.jpg.cat...]

# %%
def get_ip(img:PILImage, pts:array): return TensorPoint(pts, sz=img.size)

# %%
def get_points(coords:array):
  coords = np.delete(coords, 0)
  points = []
  temp = []
  for cord in coords:
    temp.append(cord)
    if len(temp) == 2:
      points.append(temp)
      temp = []
  return tensor(points)

# %%
def img2txt_name(f): 
  return path/f'{str(f)}.cat'

# %%
def get_y(f:Path):
  pts = np.genfromtxt(img2txt_name(f))
  return get_points(pts)

# %%
class LabeledPnts(Tuple):
    "Basic type for a list of points in an image"
    def show(self, ctx=None, **kwargs):
        for b,l in zip(self.pnts, self.lbl):
            if l != '#na#':
              ctx = retain_type(b, self.pnts).show(ctx=ctx)
              ctx.annotate(l, b, color=kwargs.get('font_color', 'white'), size=kwargs.get('font_size', 'medium'))

        return ctx

    pnts,lbl = add_props(lambda i,self: self[i])

# %%
# def PntLblBlock(vocab=None, add_na=True):
#   return TransformBlock(type_tfms=MultiCategorize(vocab=vocab, add_na=add_na), item_tfms=PntsLabeler)

# %%
class PntsLabeler(Transform):
    def setup(self, dl): self.vocab = dl.vocab if dl.vocab else lbls
    def before_call(self): self.pnts,self.lbls = None,None
        
    def decode (self, x, **kwargs): 
        self.pnts,self.lbls = None,None
        return self._call('decodes', x, **kwargs)
    
    def decodes(self, x:TensorMultiCategory): 
        self.lbls = [self.vocab[a] for a in x]
        return x if self.pnts is None else LabeledPnts(self.pnts, self.lbls)
        
    def decodes(self, x:TensorPoint): 
        self.pnts = x
        return self.pnts if self.lbls is None else LabeledPnts(self.pnts, self.lbls)

# %%
@MultiCategorize
def decodes(self, x:LabeledPnts): return x

# %%
lbls = ['LEye', 'REye', 'Mou', 'LEar-1', 'LEar-2', 'LEar-3', 'REar-1', 'REar-2', 'REar-3' ]

# %%
def PntLblBlock(vocab=None, add_na=True):
  return TransformBlock(type_tfms=MultiCategorize(vocab=vocab, add_na=add_na), item_tfms=PntsLabeler)

# %%
PointsBlock = TransformBlock(type_tfms=TensorPoint.create, item_tfms=PointScaler)

# %%
getters = [noop, lambda o: get_y(o.name)]

# %%
# dblock = DataBlock(blocks=(ImageBlock, PointsBlock, PntLblBlock(vocab=lbls)),
#                    get_items=get_image_files,
#                    splitter=RandomSplitter(),
#                    getters=getters,
#                    n_inp=1)
dblock = DataBlock(blocks=(ImageBlock, PointsBlock, PointsBlock),
                   get_items=get_image_files,
                   splitter=RandomSplitter(),
                   getters=getters,
                   n_inp=1)

# %%
# bs=48 #for ResNet18
# bs=24 #for ResNet34
bs=120 #for ResNet34 sz224

# %%
dbunch = dblock.databunch(path, path=path, item_tfms=Resize(224), bs=bs,
                batch_tfms=[Normalize.from_stats(*imagenet_stats)])

# %%
dbunch.show_batch()

# %%
class customHead(nn.Module):
  def __init__(self):
    super().__init__()
    self.points = create_head(1024, 18)
    self.classifier = create_head(1024, 100)
  def forward(self, xb):
    pt_out = self.points(xb)
    cls_out = self.classifier(xb)
    return pt_out, cls_out

# %%
body = create_body(resnet34)

# %%
net = nn.Sequential(body, customHead())

# %%
# def myLoss(out, pts, cls):
#   CELF = CrossEntropyLossFlat()
#   loss = 0
#   pt = out[0]
#   for p in range(len(pt)):
#     pred = pt[p].view(-1, 2)
#     loss += F.mse_loss(pred, pts[p])
#   return loss
def myLoss(out, pts):
  CELF = CrossEntropyLossFlat()
  loss = 0
  pt = out[0]
  for p in range(len(pt)):
    pred = pt[p].view(-1, 2)
    loss += F.mse_loss(pred, pts[p])
  return loss

# %%
learn = Learner(dbunch, net, loss_func=myLoss, cb_funcs=[EarlyStoppingCallback])

# %%
apply_init(learn.model[1], nn.init.kaiming_normal_)

# %%
learn.freeze()

# %%
learn.lr_find()

# %%
learn.save('i')

# %%
learn.load('i');

# %%
lr = 1e-3

# %% [markdown]
# learn.fit_one_cycle(85, lr)

# %%
learn.save('rn34_stage1_224')

# %%
learn.load('rn34_stage1_224')

# %% [markdown]
# The cells below were not run.  It looks like just tuning the last layer is sufficient for the Cats keypoints.  The initial run is retained for reference.

# %%
lr = 1e-3

# %%
learn.unfreeze()
lrs = slice(lr/400,lr/4)

# %%
learn.fit_one_cycle(20, lrs, pct_start=0.8, wd=1e-2)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.457507</td>
#       <td>0.581695</td>
#       <td>00:46</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.451708</td>
#       <td>0.579070</td>
#       <td>00:46</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.465240</td>
#       <td>0.583299</td>
#       <td>00:46</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.477215</td>
#       <td>0.591314</td>
#       <td>00:46</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.468907</td>
#       <td>0.587756</td>
#       <td>00:45</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.479908</td>
#       <td>0.603791</td>
#       <td>00:46</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.498817</td>
#       <td>0.630731</td>
#       <td>00:46</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.492254</td>
#       <td>0.604574</td>
#       <td>00:46</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.476527</td>
#       <td>0.639469</td>
#       <td>00:45</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.495116</td>
#       <td>0.694031</td>
#       <td>00:46</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.503683</td>
#       <td>0.703876</td>
#       <td>00:46</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.506926</td>
#       <td>0.673680</td>
#       <td>00:46</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.510242</td>
#       <td>0.650523</td>
#       <td>00:46</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.531558</td>
#       <td>0.699516</td>
#       <td>00:45</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.538249</td>
#       <td>0.708243</td>
#       <td>00:46</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.525941</td>
#       <td>0.771675</td>
#       <td>00:46</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.529125</td>
#       <td>0.699204</td>
#       <td>00:45</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.517800</td>
#       <td>0.680097</td>
#       <td>00:46</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.472926</td>
#       <td>0.587310</td>
#       <td>00:45</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.444272</td>
#       <td>0.554698</td>
#       <td>00:46</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('rn34_stage2_224')

# %%
learn.load('rn34_stage2_224')

# %%
learn.unfreeze()

# %%
learn.fit_one_cycle(5, lrs, pct_start=0.8, wd=1e-2)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>4.738252</td>
#       <td>5.779619</td>
#       <td>00:46</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>4.597815</td>
#       <td>5.533407</td>
#       <td>00:45</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>5.433063</td>
#       <td>7.281341</td>
#       <td>00:45</td>
#     </tr>
#   </tbody>
# </table>
# No improvement since epoch 1: early stopping

# %%
learn.save('rn34_stage3_224')

# %%
learn.load('rn34_stage3_224')

# %%
x = dbunch.one_batch()

# %%
gtpts = x[1]
# gtcls = x[2]

# %%
res = learn.model(x[0])
pt = res[0][0].view(-1, 2)
# lbl = res[1][0].view(-1, 10).argmax(-1).unsqueeze(0)
# a, b, c = dbunch.decode_batch((x[0], pt.unsqueeze(0), lbl))[0]
a, b = dbunch.decode_batch((x[0], pt.unsqueeze(0)))[0]
ctx = a.show(figsize=(9,9))
b.show(ctx=ctx)

# %%
res = learn.model(x[0])
pt = res[0][0].view(-1, 2)
# lbl = res[1][0].view(-1, 10).argmax(-1).unsqueeze(0)
# a, b, c = dbunch.decode_batch((x[0], pt.unsqueeze(0), lbl))[0]
a, b = dbunch.decode_batch((x[0], pt.unsqueeze(0)))[0]
ctx = a.show(figsize=(9,9))
b.show(ctx=ctx)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-37-df56981f0413> in <module>
# ----> 1 res = learn.model(x[0])
#       2 pt = res[0][0].view(-1, 2)
#       3 # lbl = res[1][0].view(-1, 10).argmax(-1).unsqueeze(0)
#       4 # a, b, c = dbunch.decode_batch((x[0], pt.unsqueeze(0), lbl))[0]
#       5 a, b = dbunch.decode_batch((x[0], pt.unsqueeze(0)))[0]
#
# ~/anaconda3/envs/fastai2/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     539             result = self._slow_forward(*input, **kwargs)
#     540         else:
# --> 541             result = self.forward(*input, **kwargs)
#     542         for hook in self._forward_hooks.values():
#     543             hook_result = hook(self, input, result)
#
# ~/anaconda3/envs/fastai2/lib/python3.7/site-packages/torch/nn/modules/container.py in forward(self, input)
#      90     def forward(self, input):
#      91         for module in self._modules.values():
# ---> 92             input = module(input)
#      93         return input
#      94
#
# ~/anaconda3/envs/fastai2/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     539             result = self._slow_forward(*input, **kwargs)
#     540         else:
# --> 541             result = self.forward(*input, **kwargs)
#     542         for hook in self._forward_hooks.values():
#     543             hook_result = hook(self, input, result)
#
# ~/anaconda3/envs/fastai2/lib/python3.7/site-packages/torch/nn/modules/container.py in forward(self, input)
#      90     def forward(self, input):
#      91         for module in self._modules.values():
# ---> 92             input = module(input)
#      93         return input
#      94
#
# ~/anaconda3/envs/fastai2/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     539             result = self._slow_forward(*input, **kwargs)
#     540         else:
# --> 541             result = self.forward(*input, **kwargs)
#     542         for hook in self._forward_hooks.values():
#     543             hook_result = hook(self, input, result)
#
# ~/anaconda3/envs/fastai2/lib/python3.7/site-packages/torch/nn/modules/container.py in forward(self, input)
#      90     def forward(self, input):
#      91         for module in self._modules.values():
# ---> 92             input = module(input)
#      93         return input
#      94
#
# ~/anaconda3/envs/fastai2/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     539             result = self._slow_forward(*input, **kwargs)
#     540         else:
# --> 541             result = self.forward(*input, **kwargs)
#     542         for hook in self._forward_hooks.values():
#     543             hook_result = hook(self, input, result)
#
# ~/anaconda3/envs/fastai2/lib/python3.7/site-packages/torchvision/models/resnet.py in forward(self, x)
#      65
#      66         if self.downsample is not None:
# ---> 67             identity = self.downsample(x)
#      68
#      69         out += identity
#
# ~/anaconda3/envs/fastai2/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     539             result = self._slow_forward(*input, **kwargs)
#     540         else:
# --> 541             result = self.forward(*input, **kwargs)
#     542         for hook in self._forward_hooks.values():
#     543             hook_result = hook(self, input, result)
#
# ~/anaconda3/envs/fastai2/lib/python3.7/site-packages/torch/nn/modules/container.py in forward(self, input)
#      90     def forward(self, input):
#      91         for module in self._modules.values():
# ---> 92             input = module(input)
#      93         return input
#      94
#
# ~/anaconda3/envs/fastai2/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     539             result = self._slow_forward(*input, **kwargs)
#     540         else:
# --> 541             result = self.forward(*input, **kwargs)
#     542         for hook in self._forward_hooks.values():
#     543             hook_result = hook(self, input, result)
#
# ~/anaconda3/envs/fastai2/lib/python3.7/site-packages/torch/nn/modules/batchnorm.py in forward(self, input)
#      79             input, self.running_mean, self.running_var, self.weight, self.bias,
#      80             self.training or not self.track_running_stats,
# ---> 81             exponential_average_factor, self.eps)
#      82
#      83     def extra_repr(self):
#
# ~/anaconda3/envs/fastai2/lib/python3.7/site-packages/torch/nn/functional.py in batch_norm(input, running_mean, running_var, weight, bias, training, momentum, eps)
#    1668     return torch.batch_norm(
#    1669         input, weight, bias, running_mean, running_var,
# -> 1670         training, momentum, eps, torch.backends.cudnn.enabled
#    1671     )
#    1672
#
# RuntimeError: CUDA out of memory. Tried to allocate 24.00 MiB (GPU 0; 7.80 GiB total capacity; 6.89 GiB already allocated; 20.44 MiB free; 170.93 MiB cached)
